# %% [markdown]
# # Contranst Enhancement

# %%
# imports
import numpy as np 
import matplotlib.pyplot as plt 
from PIL import Image

# %% [markdown]
# ## get inputs

# %%
# read inputs
beans = Image.open('data/Beans.png').convert('LA')

# %%
# convert inputs
beans_arr = np.asarray(beans)
beans_arr = beans_arr[:,:,0]

# %%
# show input 
plt.imshow(beans_arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# ## visualize data

# %%
beans_flat = beans_arr.flatten()
plt.hist(beans_flat, bins=255, range=(0,255))
plt.show()

# %% [markdown]
# ## contrance enhancement

# %% [markdown]
# #### find hist arr

# %%
def get_hist(flat_arr):
    histogram = np.zeros(256)
    for i in flat_arr:
        histogram[i] += 1
    return histogram
hist = get_hist(beans_flat)
plt.plot(hist)
plt.show()

# %% [markdown]
# #### normalize cumulative sum

# %%
norm = cs / cs.max() * 255
plt.plot(norm)

# %%
# convert normalized data to int 
norm.astype('uint8')
plt.plot(norm)

# %% [markdown]
# #### create new image

# %%
new_img = norm[beans_flat]
plt.hist(new_img, bins=255, range=(0,255))
plt.show()

# %%
# reshape the new image
new_img = np.reshape(new_img, beans_arr.shape)

# %%
plt.imshow(new_img, cmap='gray', vmin=0, vmax=255)
plt.show()
